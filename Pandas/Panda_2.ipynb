# %%
import pandas as pd

df = pd.read_csv('student_completed_data.csv')
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
#Location ghor a Dhaka aca k k
df.loc[df['Location'].str.contains("Dhaka")]
# Out:
#    StudentID       FullName CompletionStatus EnrollmentDate FinishedDate  \
# 1     PH0002  Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003  Imran Hossain        Completed     2024-05-08   2024-08-08
# 8     PH0009     Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010   Priya Sharma        Completed     2024-06-19   2024-08-19
# 12    PH0013   Tanvir Ahmed        Completed     2024-06-07   2024-08-03
# 17    PH0018    Babul Ahmed        Completed     2024-06-23   2024-09-20
#
#    Instructor Location  Total Marks
# 1   Mr. Karim    Dhaka          271
# 2   Ms. Salma    Dhaka          269
# 8   Mr. Karim    Dhaka          291
# 9   Mr. David    Dhaka          286
# 12  Mr. David    Dhaka          248
# 17  Mr. David    Dhaka          278

# %%
#case sencetive hobar jonno False 
df.loc[df['Location'].str.contains("dhaka", case=False)]
# Out:
#    StudentID       FullName CompletionStatus EnrollmentDate FinishedDate  \
# 1     PH0002  Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003  Imran Hossain        Completed     2024-05-08   2024-08-08
# 8     PH0009     Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010   Priya Sharma        Completed     2024-06-19   2024-08-19
# 12    PH0013   Tanvir Ahmed        Completed     2024-06-07   2024-08-03
# 17    PH0018    Babul Ahmed        Completed     2024-06-23   2024-09-20
#
#    Instructor Location  Total Marks
# 1   Mr. Karim    Dhaka          271
# 2   Ms. Salma    Dhaka          269
# 8   Mr. Karim    Dhaka          291
# 9   Mr. David    Dhaka          286
# 12  Mr. David    Dhaka          248
# 17  Mr. David    Dhaka          278

# %%
df.loc[df['Location'].str.contains(r"^Khu")]  #^ata sudhu first a ja suru hoicea ota print korar jonno
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 16    PH0017       Afsana Mimi        Completed     2024-01-18   2024-03-16
# 19    PH0020       Tariq Hasan        Completed     2024-07-21   2024-10-11
#
#    Instructor Location  Total Marks
# 0   Ms. Salma   Khulna          300
# 3   Mr. Karim   Khulna          270
# 5   Mr. David   Khulna          272
# 7   Ms. Salma   Khulna          246
# 16  Mr. David   Khulna          236
# 19  Mr. Karim   Khulna          253

# %%
df.loc[df['Location'].str.contains(r"am$")]  # $ata sudhu last a ja ses hoicea ota print korar jonno
# Out:
#   StudentID        FullName CompletionStatus EnrollmentDate FinishedDate  \
# 6    PH0007  Mahmudul Hasan        Completed     2024-06-07   2024-07-20
#
#   Instructor    Location  Total Marks
# 6  Mr. David  Chattogram          249

# %%
#name start with voual 
df.loc[df['FullName'].str.contains(r"^[AEIOU]")]
# Out:
#    StudentID       FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001    Alif Rahman        Completed     2024-09-01   2024-12-23
# 2     PH0003  Imran Hossain        Completed     2024-05-08   2024-08-08
# 8     PH0009     Omar Faruq        Completed     2024-02-12   2024-06-08
# 13    PH0014     Urmi Akter        Completed     2024-01-04   2024-03-23
# 16    PH0017    Afsana Mimi        Completed     2024-01-18   2024-03-16
#
#    Instructor Location  Total Marks
# 0   Ms. Salma   Khulna          300
# 2   Ms. Salma    Dhaka          269
# 8   Mr. Karim    Dhaka          291
# 13  Mr. David   Sylhet          285
# 16  Mr. David   Khulna          236

# %%
#Str contains Dha and khu
df.loc[df['Location'].str.contains(r"Dha|Khu")]
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 12    PH0013      Tanvir Ahmed        Completed     2024-06-07   2024-08-03
# 16    PH0017       Afsana Mimi        Completed     2024-01-18   2024-03-16
# 17    PH0018       Babul Ahmed        Completed     2024-06-23   2024-09-20
# ...

# %% [markdown]
# ### Adding New Column

# %%
df = pd.read_csv('student_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#adding a country column
df['Country'] = 'Bangladesh'
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['Total Marks'] = df['Data Structure Marks'] + df['Python Marks'] + df['Algorithm Marks']
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Jara Data structure a A+ 
import numpy as np
df['A+ in Ds'] = np.where(df['Data Structure Marks'] > 90 , 'A+' , 'A' )
df.drop('Grade', axis=1, inplace=True) #grade olumn delete korar jonno

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['Passed in DS'] = df['Data Structure Marks'] > 90
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['First Name'] = df['FullName'].str.split(' ').str[0]  #First name a er akta column save korar jonno
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.to_csv('new_data.csv') #new csv save korar jonno
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# ### unique and null Checking

# %%
data = {
    "Name":['Alice', 'Bob', "Charlie", "Alice" , "David", "Bob"],
    "City":["New York", "London","PAris","New York","Tokeyo","London"],
    "Score":[85,90,78,85,95,90]
}

df = pd.DataFrame(data)
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     PAris     78
# 3    Alice  New York     85
# 4    David    Tokeyo     95
# 5      Bob    London     90

# %%
df['Name'].unique()
len(df['Name'].unique())
# Out:
# 4

# %%
df = pd.read_csv('student_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#koita DS er mark unique

df['Data Structure Marks'].nunique()
# Out:
# 12

# %%
df['FullName'].nunique()
# Out:
# 20

# %% [markdown]
# ### Null Check

# %%
df.isnull()
# Out:
#     StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       False     False                 False            False         False
# 1       False     False                 False            False          True
# 2       False     False                 False            False         False
# 3       False     False                 False            False         False
# 4       False     False                  True             True         False
# 5       False     False                 False            False         False
# 6       False     False                 False            False          True
# 7       False     False                 False            False         False
# 8       False     False                 False            False         False
# 9       False     False                 False            False         False
# 10      False     False                  True             True         False
# ...

# %%
#akta column er null check
df['Data Structure Marks'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Data Structure Marks, dtype: bool

# %%
#null na holea true hlea False return
df['Data Structure Marks'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# Name: Data Structure Marks, dtype: bool

# %%
df['StudentID'].hasnans #akta value null thaklea true dibea
# Out:
# False

# %% [markdown]
# ### Handle Duplicate values

# %%
data1 = {
    "Name":['Alice', 'Bob', "Charlie", "Alice" , "David", "Bob"],
    "City":["New York", "London","PAris","New York","Tokeyo","London"],
    "Score":[85,90,78,85,95,90]
}
df = pd.DataFrame(data1)
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     PAris     78
# 3    Alice  New York     85
# 4    David    Tokeyo     95
# 5      Bob    London     90

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
#delete dublicate 
df.drop_duplicates()
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     PAris     78
# 3    Alice  New York     85
# 4    David    Tokeyo     95
# 5      Bob    London     90

# %%
df.drop_duplicates(inplace=True)  #ata parmanent delete korar honno
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     PAris     78
# 4    David    Tokeyo     95

# %%
df.drop_duplicates(subset=['Name'], keep = 'last') #column Name er duplicate delete korar jonno keep sudhu last er value rakhar jonno
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     PAris     78
# 4    David    Tokeyo     95

# %% [markdown]
# ### Handle Nullvalues

# %%
df = pd.read_csv('student_data.csv')

# Add empty row without warning
df.loc[len(df)] = None

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.dropna() #Null row er value gulo delete korea
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
df.dropna(how='all',inplace = True) #jaikhan a sob nul aca and permanntly delete korbea
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Column wise delete korar jnonno
df.dropna(subset=['Python Marks', 'Algorithm Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
df.fillna(45.6)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                  45.6             45.6
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                  45.6             45.6
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df = pd.read_csv('student_data.csv')

# Add empty row without warning
df.loc[len(df)] = None

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#string fill korar jono
df['FullName'].fillna('unknown')
# Out:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# 20             unknown
# Name: FullName, dtype: object

# %%
df['Python Marks'].fillna(df['Python Marks'].mean(),inplace=True) #null value ta bakider value dia fill korar jonno

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# ### Statistical Function

# %%
df.dropna()
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# ...

# %%
df['Data Structure Marks'].sum() #total sum ber korar jonno
# Out:
# np.float64(1344.0)

# %%
#max and min ber korar jonno
print(df['Data Structure Marks'].min()) 
df['Data Structure Marks'].max()
# Out:
# 72.0
# 94.0

# %%
#mean ber korar jonno
print(df['Data Structure Marks'].median())
df['Data Structure Marks'].mean()
# Out:
# 85.5
# np.float64(84.0)

# %%
#sob thakea kon value aca
df['Data Structure Marks'].mode()
# Out:
# 0    75.0
# 1    85.0
# 2    86.0
# 3    88.0
# Name: Data Structure Marks, dtype: float64

# %%
#Standard deviation
df['Data Structure Marks'].std()
# Out:
# 6.501281924871945

# %%
#correlation matricx
df[['Data Structure Marks','Python Marks']].corr()
# Out:
#                       Data Structure Marks  Python Marks
# Data Structure Marks              1.000000      0.776845
# Python Marks                      0.776845      1.000000

# %%
#sum in different column row wise
df[['Data Structure Marks','Python Marks']].sum(axis=1)
# Out:
# 0     173.000000
# 1     177.666667
# 2     173.000000
# 3     160.000000
# 4      95.000000
# 5     153.000000
# 6     165.666667
# 7     166.000000
# 8     148.000000
# 9     177.000000
# 10     91.000000
# 11    172.000000
# 12    154.000000
# 13     85.666667
# 14    170.000000
# 15    179.666667
# 16    183.000000
# 17    173.000000
# 18     85.666667
# 19    175.000000
# 20     85.666667
# dtype: float64

# %%
# 3ta column + korar jonno
df['Total Marks'] = df.iloc[::,2:5].std(axis=1) #mean median mod sob ber kora jai same vabea

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.describe() #ata dea statistics er sob paya jai
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks  Total Marks
# count             16.000000        16.000000     21.000000    16.000000
# mean              84.000000        84.000000     85.666667     2.141007
# std                6.501282         6.501282      4.512944     1.039646
# min               72.000000        72.000000     76.000000     0.577350
# 25%               79.500000        79.500000     85.000000     1.732051
# 50%               85.500000        85.500000     85.666667     1.732051
# 75%               88.250000        88.250000     88.000000     2.309401
# max               94.000000        94.000000     95.000000     4.811252

# %% [markdown]
# ### Apply Function on DF

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#min max scealing
mn=df['Total Marks'].min()
mx=df['Total Marks'].max()

df['Scaled Marks'] = df['Total Marks'].apply(lambda x : (mn-x)/(mx-mn))
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#custon build function

def grading_system(marks):
    if marks>=260:
        return 'A+'
    elif marks>=250:
        return 'A'
    else:
        return 'A-'

df['Grade'] = df['Total Marks'].apply(grading_system)

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# ### Date and Time

# %%
df['EnrollmentDate']
# Out:
# 0     2024-01-15
# 1     2024-01-20
# 2     2024-02-10
# 3     2024-02-12
# 4     2024-03-05
# 5     2024-03-08
# 6     2024-04-01
# 7     2024-04-22
# 8     2024-05-16
# 9     2024-05-20
# 10    2024-06-11
# 11    2024-06-14
# 12    2024-07-02
# 13    2024-07-09
# 14    2024-08-18
# 15    2024-08-21
# 16    2025-09-01
# 17    2025-09-05
# 18    2025-09-15
# 19    2025-10-02
# 20           NaN
# Name: EnrollmentDate, dtype: object

# %%
df['EnrollmentDate'] = pd.to_datetime(df['EnrollmentDate'])

# %%
df['EnrollmentDate']
# Out:
# 0    2024-01-15
# 1    2024-01-20
# 2    2024-02-10
# 3    2024-02-12
# 4    2024-03-05
# 5    2024-03-08
# 6    2024-04-01
# 7    2024-04-22
# 8    2024-05-16
# 9    2024-05-20
# 10   2024-06-11
# 11   2024-06-14
# 12   2024-07-02
# 13   2024-07-09
# 14   2024-08-18
# 15   2024-08-21
# 16   2025-09-01
# 17   2025-09-05
# 18   2025-09-15
# 19   2025-10-02
# 20          NaT
# Name: EnrollmentDate, dtype: datetime64[ns]

# %%
df['Buying Year'] = df['EnrollmentDate'].dt.year

# %%
df['Buying day'] = df['EnrollmentDate'].dt.day
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Baki aca r o date Time er

# %% [markdown]
# ### Gropy By Panda

# %%
inport numpy as np 
df.loc[df['FullName'] == 'Afsana Mimi','Total Marks'] = np.nan
df.loc[df['FullName'] == 'Sadia Chowdhury','Total Marks'] = np.nan
df.loc[df['FullName'] == 'Alif Rahman','Total Marks'] = np.nan

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
instractor_group = df.groupby('Instructor')
instractor_group

# %%
for instractor , z in instractor_group:
    print(instractor)
    display(z)
# Out:
# Mr. David
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 8     PH1009    Omar Faruq                  72.0             72.0
# 12    PH1013  Tanvir Ahmed                  75.0             75.0
# 18    PH1019  Faria Rahman                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 8      76.000000        Completed     2024-05-16  Mr. David       Dhaka
# 12     79.000000        Completed     2024-07-02  Mr. David       Dhaka
# 18     85.666667      Not Started     2025-09-15  Mr. David  Chattogram
#
#     Total Marks  Scaled Marks Grade  \
# 8      2.309401     -0.409091    A-
# 12     2.309401     -0.409091    A-
# 18          NaN           NaN    A-
#
#                                      Exceptional mark  Buying Year  Buying day
# 8   [Data Structure Marks, Data Structure Marks, P...       2024.0        16.0
# 12  [Data Structure Marks, Data Structure Marks, P...       2024.0         2.0
# ...

# %%
instractor_group.min()
# Out:
#            StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# Instructor
# Mr. David     PH1009  Faria Rahman                  72.0             72.0
# Mr. Karim     PH1001   Afsana Mimi                  80.0             80.0
# Ms. Salma     PH1002   Babul Ahmed                  75.0             75.0
#
#             Python Marks CompletionStatus EnrollmentDate    Location  \
# Instructor
# Mr. David           76.0        Completed     2024-05-16  Chattogram
# Mr. Karim           84.0        Completed     2024-01-15  Chattogram
# Ms. Salma           78.0        Completed     2024-01-20  Chattogram
#
#             Total Marks  Scaled Marks Grade  \
# Instructor
# Mr. David      2.309401     -0.409091    A-
# Mr. Karim      1.154701     -0.636364    A-
# Ms. Salma      0.577350     -1.000000    A-
#
#                                              Exceptional mark  Buying Year  \
# Instructor
# Mr. David   [Data Structure Marks, Data Structure Marks, P...       2024.0
# ...

# %%
instractor_group.describe()
# Out:
#            Data Structure Marks                                             \
#                           count       mean   min    25%   50%    75%   max
# Instructor
# Mr. David                   2.0  73.500000  72.0  72.75  73.5  74.25  75.0
# Mr. Karim                   5.0  85.800000  80.0  85.00  86.0  88.00  90.0
# Ms. Salma                   9.0  85.333333  75.0  81.00  86.0  89.00  94.0
#
#                      Algorithm Marks             ... Buying Year            \
#                  std           count       mean  ...         max       std
# Instructor                                       ...
# Mr. David   2.121320             2.0  73.500000  ...      2025.0  0.577350
# Mr. Karim   3.768289             5.0  85.800000  ...      2025.0  0.377964
# Ms. Salma   6.324555             9.0  85.333333  ...      2025.0  0.421637
#
#            Buying day
#                 count       mean  min   25%   50%   75%   max       std
# Instructor
# ...

# %%
mean_marks = instractor_group['Total Marks'].mean()
mean_marks
# Out:
# Instructor
# Mr. David    2.309401
# Mr. Karim    1.924501
# Ms. Salma    2.223868
# Name: Total Marks, dtype: float64

# %%
df['Total Marks'] = df['Total Marks'].fillna(df['Instructor'].map(mean_marks))
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...
